# %%
# """
# Comprehensive Core Python Tutorial
# Author: Chat Gpt

# This file is designed as a complete beginner to intermediate core python learning guide.

# Topic covered :

# 1. Python Basics
# 2. Variables and Data Types
# 3. Input and output
# 4. Operators
# 5. Conditional Statements
# 6. Loops
# 7. Strings
# 8. Tuples
# 9. Sets
# 10. Dictionaries
# 11. Functions
# 12. Lambda Functions
# 13. Exception Handling
# 14. File Handling
# 15. Lists
# 16. Object oriented Programming
# 17. Modules and packages
# 18. Useful Built In functions
# 19. List COmprehension
# 20. Iterators and generators
# 21. Decorators
# 22. Python Best Practices
# 23. Mini practice problems
# 24. final project ideas

# """
# # 1. Python Basics ====================================

# print("Hello, python")
# print("Welcome to core python tutorial")

# # 2. Variable and data types ================================

# # variable store values
# name = "Nav"
# age = 25
# height = 5.9
# is_student = True

# print(type(name))
# print(type(age))
# print(type(height))
# print(type(is_student))

# # Multiple assignment
# x, y,z = 10,20,30
# print(x,y,z)

# # Naming assignment
# student_name = "John"
# studentAge = 21

# # 3. Input and output ===================================

# # user_name = input("Enter your name:")
# # print("Hello", user_name)

# # # Convert input to integer
# # number = int(input("Enter a number:"))
# # print(number + 10)

# # formatted strings
# language = "Python"
# version = 3.9
# print(f" Learning {language} version {version}")

# # 4 Operators ===================================================
# # Arithmatic operators
# print(10 + 5)
# print(10 - 5)
# print(10 * 5)
# print(10 / 5)
# print(10 // 5)
# print(10 % 3)
# print(2 ** 3)

# # Comparison operators
# print(10 > 5)
# print(10 < 5)
# print(10 == 10)
# print(10 != 5)

# # Logical Operators
# print(True and False)
# print(True or False)
# print(not True)

# # Assignment Operator
# num = 10
# num +=5
# print(num)

# # Membership operators
# text = "Python"
# print("p" in text)
# print("z" not in text)

# # 5 conditional statements ==================================

# age = 18

# if age >= 18:
#   print("you are eligible to vite")

# else:
#   print("not allowed")

# marks = 75

# if marks >= 90:
#   print("Grade A")
# elif marks >= 80:
#   print("Grade B")
# elif marks >= 50:
#   print("Grade C")
# else:
#   print("Fail please retake")

# # Nested if
# number = 10

# if number > 0:
#   if number % 2 == 0:
#     print("Positive Even Number")

# # 6. Loops =====================================================

# # for loop
# for i in range(5):
#   print("Iteration:", i)

# # While loop
# count = 0

# while count < 3:
#   print('coint:', count)
#   count +=1

# # break statement
# for i in range(5):
#   if i == 5:
#     break
#   print(i)

# # continue statemnt
# for i in range(5):
#   if i == 2:
#     continue
#   print(i)

# # pass statement
# for i in range(5):
#   pass

# # 7. Strings ==============================================

# message = " Python programming"

# print(message)
# print(message[0])
# print(message[-1])
# print(len(message))

# # String slicing
# print(message[0:6])
# print(message[7:])
# print(len(message[:6]))

# # String methods
# print(message.upper())
# print(message.lower())
# print(message.replace("Python", "Java"))
# print(message.split())

# # checking constant
# print(message.startswith("python"))
# print(message.endswith("ing"))

# # String concatenation
# first = "Hello"
# second = "World"
# print(first + " "+ second)

# # 8 Lists ========================================================

# fruits = ["apple", "banana", "mango"]

# print(fruits)
# print(fruits[0])

# # Modify list
# fruits[1] = "orange"
# print(fruits)

# # Add elements
# fruits.append("grapes")
# print(fruits)

# fruits.insert(1, "liwi")
# print(fruits)

# # Remove element
# fruits.remove("apple")
# print(fruits)

# popped_item = fruits.pop()
# print(popped_item)
# print(fruits)

# # list slicing
# numbers = [1,2,3,4,5,6]
# print(numbers[1:4])

# # Loop through list
# numbers = [1,2,3,4,5,6]
# print(numbers[1:4])

# # loop through list
# for fruits in fruits:
#   print(fruits)

# # list methods
# num.reversed()
# print(nums)

# # 9. Tuples
# coordinate = (10, 20)
# print(coordinates)
# print(coordinates[0])

# # Tuple are immutable
# # Coordinates[0] = 50  # 50

# # Tuple unpacking
# x, y = coordinates
# print(x, y)

# # 10. Sets ===================================
# unique_numbers = {1,2,3,4}
# print(unique_numbers)

# unique_numbers.add(5)
# print(unique_numbers)

# unique_numbers.remove(2)
# print(unique_numbers)

# # set operation
# set1 = {1,2,3}
# set2 = {3,4,5}

# print(set1.union(set2))
# print(set1.intersection(set2))
# print(set.difference(set2))

# # 11. Dictinaries ==============================

# student = {
#     "name": "Nav",
#     "age": 25,
#     "course": "python"

# }

# print(student)
# print(student["name"])

# # Add / update values
# student["age"] = 26
# student["city"] = "Pune"

# print(students)

# # Dictionary methods
# print(student.keys())
# print(student.values())
# print(student.items())

# # Loop through dictionary
# for key, value in student.items():
#   print(key, value)

# # 12 Functions ===================================

# # simple function

# def greet():
#   print("hello from function")

# greet()

# # Function with parameters

# def add(a, b):
#   return a + b

# result = add(10, 20)
# print(result)

# # default arguments

# def introduce(name, country = "India"):
#   print(f"My name is {name} an I lve in {country}")

# introduce("Nav")
# introduce("John", "USA")

# # Arbitrary agruments

# def total_sum(*number):
#   return sum(numbers)

# print(total_sum(1,2,3,4,5))

# # Default keyword arguement
# def profile(**details):
#   print(details)

# profile(name = "Nav", skills = "Python")

# # 13 lambda functions =====================================

# square = lambda x: x * x
# print(square(5))

# add_numbers = lambda a, b: a + b
# print(add_numbers(10, 20))

# # using lambda with map
# numbers = [1,2,3,4]
# squared = list(map(lambda x: x * x, numbers))
# print(squared)

# # Using lambda with filter
# #odd_numbers = list(filter(lambda x: x % 2 ! = 0, numbers))
# print(odd_numbers)

# # 14 Exceptin handling
# try:
#   num = int("10")
#   result = 10 /2
#   print(result)

# except ValueError:
#   print("Invalid number Make sure ")

# except ZeroDivisionError:
#   print("Cannot divide by zero")

# finally:
#   print("Exceution completed")

# # Custome exception example
# try:
#   age = -1

#   if age < 0:
#     raise ValueError("Age cannot be negative")

#   except ValueError as e:
#     print(e)

#   # 15. File handling

#   # writing to file
#   with open("sample.txt", "w") as file:
#     file.write("Hello file handling")

#   # Reading from file
#   with open("sample.txt", "r") as file:
#     content = file.read()
#     print(content)

#   # appending to file
#   with open("Same.txt", "a") as file:
#     file.write("\n new line added")

#   # 16. Object oriented programming
#   # creating a class

#   class student:
#     def __init__(self, name, marks):
#       self.name = name
#       self.marks = marks

#     # instance method
#     def display(self):
#       print(f"name: "{slef.name})
#       print(f"marks: {self.marks}")

#     def is_passed(self):
#       return self.marks >= 40

#     # creating objects
#     student1 = student("Nav", 85)
#     student2 = student("john", 35)

#     student1.display()
#     print(student1.is_passed)

#     student2.display()
#     print(student2.is_passed())

#     # Inheritance
#     class Animal:
#       def speak(self):
#         print("Animal speaks")

#     class Dog(Animal):

#       def bark(self):
#         print("Dog barks")

# my_dog = Dog()
# my_dog.speak()
# my_dog.bark()

# # Encapsulation
# class BankAccount:
#   def__ init__(self, balance):
#     self.__balance = __balance

#   def deposit(self, amount):
#     self.__balance += amount

#   def get_balance(self):
#     return self.__balance

#   account = BankAccount(1000)
#   account.deposit(500)
#   print(acount.get_balanced())

#   # 17 Modules and packages

#   import math
#   import random

#   print(math.sqrt(25))
#   print(math.pi)

#   print(random.randint(1, 10))

#   # aliasing module
#   import datetime as dt

#   print(dt.datetime.now())

#   # 18. Useful built in function

#   numbers = [1,2,3,4,5]

#   print(print(len(numbers)))
#   print(max(numbers))
#   print(min(numbers))
#   print(sum(numbers))
#   print(sorted(numbers, reverse=True))

#   # zip function
#   names = ["Alice", "Bob"]
#   scores = [90, 85]

#   combined = list(zip(names, scores))
#   print(combines)

#   # enumerate function
#   for index, value in enumerate(names):
#     print(index, value)

#   # 19. List function
#   squares = [x ** 2 for x in range(10)]
#   print(squares)

#   # With condition
#   odd_numbers = [x for x in range(20) if x % 2 !=0]
#   print(odd_numbers)

#  # dictionary comprehension
#  squares_dict = {x: x ** 2 for x in range(5)}
#  print(square_dict)

# # 20 iterators and generators
# #iterators example

# numbers = [1,2,3]
# iterator = iter(numbers)

# print(next(iterator))
# print(next(iterator))
# print(next(iterator))

# # Genrators exmaple

# def count_up_to(n):
#   count = 1

#    while count <= n:
#     yield = 1
#     count += 1

# for number in count_up_to(5):
#   print(number)

# # 21 ddecorators

# # Decorators function

# def decorator_funtion(original_funtion):

#   def wrapper_function():
#     print("Before function excecution")
#     original_function()
#     print("After function excecution")

# return wrapper_function

# @decorator_function
# def display_message():
#   print("Hello from decorator function")

# display_message()

# Thanks for ypur patience
# Out:
#   File "/tmp/ipykernel_3547/2920632906.py", line 343
#     odd_numbers = list(filter(lambda x: x % 2 ! = 0, numbers))
#                                               ^
# SyntaxError: invalid syntax
